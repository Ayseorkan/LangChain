# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o", temperature=0)

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages(
  [
      ("system", "You are world class technical documentation writer."),
      ("user", "{input}")
  ]

)

# %%
from langchain_core.output_parsers import StrOutputParser

StrOutputParser()
# Out:
# StrOutputParser()

# %%
chain = prompt | model | StrOutputParser()

# %%
print(chain.invoke({"input": "What is LangGraph"}))
# Out:
# LangGraph is an open-source framework designed to facilitate the creation and management of large language model (LLM) applications. It provides a structured environment for developers to build, deploy, and scale applications that leverage the capabilities of LLMs. LangGraph offers a range of tools and features that simplify the integration of language models into various applications, enabling developers to focus on building innovative solutions without getting bogged down by the complexities of model management and deployment.
#
# Key features of LangGraph typically include:
#
# 1. **Modular Architecture**: LangGraph is built with a modular design, allowing developers to easily plug in different components and customize their applications according to specific needs.
#
# 2. **Scalability**: The framework is designed to handle large-scale applications, making it suitable for enterprise-level deployments that require robust performance and reliability.
#
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://blog.langchain.com/langgraph/")   #retrival technique to get the data from the web page
data = loader.load()
data
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ...

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
documents = text_splitter.split_documents(data)

# %%
documents
# Out:
# [Document(metadata={'source': 'https://blog.langchain.com/langgraph/', 'title': 'LangGraph', 'language': 'en'}, page_content="LangGraph\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWebsite\n\n\n\n\nDocs\n\n\n\n\nCase Studies\n\n\n\n\nHarrison's Hot Takes\n\n\n\n\nTry LangSmith\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLangGraph\n\nBy LangChain\n7 min read\nJan 17, 2024"),
# ...

# %%
vector=FAISS.from_documents(documents, embeddings)

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template(
    """
    Answer the question based on the context below.
    Context: {context}
    Question: {question}
    """)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

# retriever
retriever = vector.as_retriever(search_kwargs={"k": 4})

# prompt
prompt = ChatPromptTemplate.from_template("""
Answer the question based only on the context:

{context}

Question: {question}
""")

# chain
rag_chain = (
    {
        "context": retriever,
        "question": RunnablePassthrough()
    }
    | prompt
    | model
)

rag_chain.invoke("What is LangGraph?")
# Out:
# AIMessage(content='LangGraph is a module built on top of LangChain designed to enable the creation of cyclical graphs, which are often needed for agent runtimes. It is completely interoperable with the LangChain ecosystem and adds value by providing an easy way to create these cyclical graphs. LangGraph allows for more controlled flows, referred to as "state machines," which can handle more ambiguous inputs than simple chains by allowing loops and human guidance in their construction.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 89, 'prompt_tokens': 1003, 'total_tokens': 1092, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_c7d0c94d9d', 'id': 'chatcmpl-DEJeV5hvxpM8NEP8OmJ2XfA12fyEU', 'service
# ...

# %%
from langchain_core.documents import Document
my_doc = Document(page_content="This is a test document", metadata={"source": "test"})
my_doc.page_content 
my_doc.metadata
# Out:
# {'source': 'test'}

# %%
rag_chain = prompt | model
rag_chain.invoke(
    {
     "context": my_doc.page_content,
        "question": "What is this document about?"
     
     })
# Out:
# AIMessage(content='The document is a test document.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 31, 'total_tokens': 38, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f032d30a59', 'id': 'chatcmpl-DEJmAldqk6aLyH4cbsVd5hWmdkB1m', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ca59b-e05f-7b82-a192-e4715a905b8d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 7, 'total_tokens': 38, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
