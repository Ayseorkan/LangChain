# %%
from dotenv import load_dotenv   
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(temperature=0.9)
text="Tell me a joke about programming."
response = llm.invoke(text)
print(response.content)
# Out:
# Why do programmers prefer dark mode? Because the light attracts bugs!

# %%
llm = ChatOpenAI(
    temperature=0.7,
    model_name="gpt-4o",
    max_retries=3,
    request_timeout=120,
)
response = llm.invoke("What is the most popular programming language in 2025?")
print(response.content)
# Out:
# I’m unable to provide real-time information or predict future events, including the most popular programming language in 2025. However, as of my last update, popular programming languages included Python, JavaScript, Java, C#, and others. Trends in programming languages can be influenced by various factors such as industry demand, technological advancements, community support, and educational resources. To find the most popular programming language in 2025, you may want to consult industry reports, developer surveys, or tech news sources closer to that time.

# %%
from langchain_core.messages import HumanMessage
message = HumanMessage(content="Hello, how are you?")
response = llm.invoke([message])
print(response.content)
# Out:
# Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?

# %%
from langchain_openai import ChatOpenAI, OpenAI 
llm=OpenAI()
chat_model=ChatOpenAI()

llm.invoke(text)
# Out:
# "\n\nWhy did the programmer quit his job?\n\nBecause he didn't get arrays."

# %%
chat_model.invoke(text)
# Out:
# AIMessage(content='Why do programmers prefer dark mode? \n\nBecause the light attracts bugs!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 14, 'total_tokens': 28, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CukZ4EESXmN7uqFmKJaRsbCgLADBw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8fa3-3bce-7db2-b5d7-47d0da6119fc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 14, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
